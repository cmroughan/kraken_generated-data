# %%
import datetime
from IPython.display import Image

# %% [markdown]
# # Example Model from Fonts
#
# Christine Roughan (2019)
#
# This notebook records an example of the kinds of results I was able to accomplish in the summer of 2019 with the Kraken OCR software and automatically-generated training data.
#
# Many of these cells run Bash commands instead of Python -- see any cell which starts with `!`. I interspersed cells to print the current time so that I would have a record of how long it took for Kraken to train each model.
#
# The first two cells below print out examples of the training data that will be used to train an OCR model from two fonts, [Amiri](https://www.amirifont.org/) and [Scheherazade](https://software.sil.org/scheherazade/). The text itself is gibberish, because I have randomly added characters to have a more representative sample when training the OCR model. The third cell shows what the typeface looks like for one text I want to OCR.

# %%
# A sample of one line (Amiri font), in its txt file and png file
inFile = open('from-font/amiri/000088.gt.txt')
print(inFile.read())
inFile.close()
Image(filename='from-font/amiri/000088.png')
# Out:
#  تبيّن انه(٥) يكون — وتران (ت ز ج) فى (ص خ) دائرة "يقطع" إحدهما ألاخر

# %%
# A sample of one line (Scheherazade font), in its txt file and png file
inFile = open('from-font/scheherazade/000026.gt.txt')
print(inFile.read())
inFile.close()
Image(filename='from-font/scheherazade/000026.png')
# Out:
#  يوتّرهاء الضلع إلاعظم وذلك بحسب برهان(٤) يط(*) من ا(٤) يكون خط هد

# %%
# A line of the target text to be OCRed
# line from: Ẓāhirāt al-falak li-Uqlīdis. Ed. Sulaymān. Beirut: 1996.
Image(filename='phaenomena/n5pgs/000000.png')

# %% [markdown]
# ______________
#
# ## Step 1: Training from data generated from fonts
#
# Here, the model trains on two fonts at the same time. A comparison of the start and completion times shows that this training step completes in just over three and a half hours. The final accuracy rate for these fonts is measured at 99.787%.

# %%
print('Time at start of below:\n\t',datetime.datetime.now())
# Out:
# Time at start of below:
# 	 2019-09-16 23:03:10.300101

# %%
# !ketos train -o out/1/model from-font/*/*.png
# Out:
# Building training set  [####################################]  100%
# [1.8084] alphabet mismatch: chars in training set only: {'آ', 'ٰ', 'ؤ'} (not included in accuracy test during training)
# Initializing model ✓
# stage 1/∞  [####################################]  2473/2473          Accuracy report (1) 0.9509 18797 922
# stage 2/∞  [####################################]  2473/2473           Accuracy report (2) 0.9842 18797 297
# stage 3/∞  [####################################]  2473/2473           Accuracy report (3) 0.9911 18797 168
# stage 4/∞  [####################################]  2473/2473            Accuracy report (4) 0.9945 18797 103
# stage 5/∞  [####################################]  2473/2473            Accuracy report (5) 0.9948 18797 97
# stage 6/∞  [####################################]  2473/2473            Accuracy report (6) 0.9962 18797 72
# stage 7/∞  [####################################]  2473/2473            Accuracy report (7) 0.9963 18797 69
# stage 8/∞  [####################################]  2473/2473            Accuracy report (8) 0.9968 18797 61
# stage 9/∞  [####################################]  2473/2473            Accuracy report (9) 0.9968 18797 60
# stage 10/∞  [####################################]  2473/2473            Accuracy report (10) 0.9974 18797 49
# stage 11/∞  [####################################]  2473/2473            Accuracy report (11) 0.9971 18797 55
# stage 12/∞  [####################################]  2473/2473            Accuracy report (12) 0.9970 18797 56
# stage 13/∞  [####################################]  2473/2473            Accuracy report (13) 0.9977 18797 44
# stage 14/∞  [####################################]  2473/2473            Accuracy report (14) 0.9977 18797 44
# stage 15/∞  [####################################]  2473/2473            Accuracy report (15) 0.9979 18797 40
# stage 16/∞  [####################################]  2473/2473            Accuracy report (16) 0.9979 18797 39
# stage 17/∞  [####################################]  2473/2473            Accuracy report (17) 0.9978 18797 42
# stage 18/∞  [####################################]  2473/2473            Accuracy report (18) 0.9977 18797 44
# stage 19/∞  [####################################]  2473/2473            Accuracy report (19) 0.9974 18797 48
# stage 20/∞  [####################################]  2473/2473            Accuracy report (20) 0.9980 18797 38
#
# Moving best model out/1/model_15.mlmodel (0.9978720008511996) to out/1/model_best.mlmodel

# %%
print('Time at completion of above:\n\t',datetime.datetime.now())
# Out:
# Time at completion of above:
# 	 2019-09-17 02:37:29.690339

# %% [markdown]
# _____________
#
# ## Step 2: Testing and Refining on Text A
#
# I first run a test of the model produced above on the training data I have already transcribed for Text A. The current model has an accuracy of 89.54% on this new data.
#
# I then refine the model with 5 pages of new training data from Text A. You can see below that this takes about five minutes (it is much less training data than above) and the updated model reaches an accuracy of 97.38% on this new data.
#
# I refine the model one more time with 5 more pages of new training data from Text A, taking another five minutes to train and reaching an accuracy rate of 99.097% (!!).

# %%
# !ketos test -m out/1/model_best.mlmodel phaenomena/5pgs/*.png
# Out:
# Loading model out/1/model_best.mlmodel	✓
# Evaluating out/1/model_best.mlmodel
# Evaluating  [####################################]  100%
# === report  ===
#
# 5421	Characters
# 567	Errors
# 89.54%	Accuracy
#
# 193	Insertions
# 155	Deletions
# 219	Substitutions
#
# Count	Missed	%Right
# 3931	282	92.83%	Arabic
# 1450	112	92.28%	Common
# 40	18	55.00%	Inherited
#
# Errors	Correct-Generated
# 34	{  } - { SPACE }
# 29	{  } - { ـ }
# 25	{ SPACE } - {  }
# 19	{ ت } - {  }
# 16	{ م } - {  }
# 14	{ أ } - { ARABIC FATHATAN }
# 14	{  } - { ا }
# 14	{ ( } - { &#34; }
# 14	{ ) } - {  }
# 14	{ ـ } - {  }
# 13	{  } - { س }
# 13	{ أ } - { ا }
# 11	{  } - { ARABIC SHADDA }
# 11	{ ث } - { ت }
# 11	{ ARABIC FATHATAN } - {  }
# 11	{ إ } - { ا }
# 10	{  } - { ت }
# 9	{  } - { ه }
# 9	{ ر } - { ز }
# 8	{ ؤ } - { و }
# 7	{ ح } - {  }
# 7	{ ب } - {  }
# 7	{ ج } - { ح }
# 5	{  } - { ل }
# 5	{ ر } - {  }
# 5	{ ه } - {  }
# 5	{ . } - {  }
# 5	{ ر } - { و }
# 5	{ . } - { SPACE }
# 5	{ : } - {  }
# 5	{ ( } - { ا }
# 5	{ ن } - {  }
# 4	{ غ } - { ف }
# 4	{ ث } - {  }
# 4	{  } - { ن }
# 4	{ ١ } - {  }
# 4	{  } - { م }
# 3	{ م } - { ARABIC SHADDA }
# 3	{ د } - { ه }
# 3	{ ٦ } - {  }
# 3	{  } - { ح }
# 3	{ س } - { ع }
# 3	{  } - { . }
# 3	{ د } - {  }
# 3	{ ) } - { &#34; }
# 3	{ ي } - {  }
# 3	{ ( } - {  }
# 3	{ — } - {  }
# 2	{ ARABIC FATHATAN } - { ARABIC SHADDA }
# 2	{ ج } - {  }
# 2	{ ٥ } - { &#34; }
# 2	{ ش } - { ت }
# 2	{ &#34; } - {  }
# 2	{ ا } - {  }
# 2	{ ئ } - { ى }
# 2	{ ج } - { ـ }
# 2	{ س } - {  }
# 2	{ د } - { ث }
# 2	{ ص } - {  }
# 2	{ س } - { م }
# 2	{  } - { و }
# 2	{ ش } - { س }
# 2	{  } - { ج }
# 2	{ ى } - {  }
# 2	{ / } - { SPACE }
# 2	{ ت } - { ق }
# 2	{ ARABIC DAMMA } - { ARABIC SHADDA }
# 2	{ ن } - { ت }
# 2	{ - } - {  }
# 2	{  } - { &#34; }
# 2	{ ئ } - {  }
# 2	{ ٣ } - { &#34; }
# 2	{ ن } - { م }
# 1	{ ة } - { ه }
# 1	{ ق } - { ه }
# 1	{ ط } - { ظ }
# 1	{ ة } - {  }
# 1	{ &#34; } - { ا }
# 1	{ SPACE } - { ـ }
# 1	{  } - { ي }
# 1	{ ز } - { و }
# 1	{ ي } - { ب }
# 1	{ ر } - { ع }
# 1	{ د } - { ل }
# 1	{ ل } - {  }
# 1	{ ح } - { ـ }
# 1	{ ث } - { ذ }
# 1	{ ه } - { ـ }
# 1	{ ح } - { خ }
# 1	{ ص } - { ا }
# 1	{ أ } - {  }
# 1	{ ه } - { ق }
# 1	{ ذ } - { ARABIC SHADDA }
# 1	{ ث } - { ز }
# 1	{ ا } - { إ }
# 1	{ أ } - { س }
# 1	{  } - { : }
# 1	{ ا } - { &#34; }
# 1	{ ذ } - {  }
# 1	{ ؤ } - { SPACE }
# 1	{ ث } - { ن }
# 1	{  } - { ق }
# 1	{ ت } - { ن }
# 1	{ ذ } - { ن }
# 1	{ ل } - { ARABIC SHADDA }
# 1	{ ل } - { SPACE }
# 1	{ ن } - { ه }
# 1	{  } - { ع }
# 1	{ ن } - { ع }
# 1	{ م } - { ل }
# 1	{ ح } - { ه }
# 1	{ م } - { أ }
# 1	{ س } - { ه }
# 1	{ ب } - { ي }
# 1	{ ع } - {  }
# 1	{ . } - { ه }
# 1	{ ٨ } - { SPACE }
# 1	{ ٢ } - { ه }
# 1	{ ١ } - { SPACE }
# 1	{ ٥ } - { ٣ }
# 1	{ ٩ } - { SPACE }
# 1	{ ٩ } - { ه }
# 1	{ ١ } - { ٨ }
# 1	{ ف } - { ل }
# 1	{ ٢ } - { &#34; }
# 1	{ ARABIC DAMMA } - { ARABIC FATHATAN }
# 1	{ ARABIC FATHA } - {  }
# 1	{ ARABIC KASRA } - {  }
# 1	{ ٣ } - {  }
# 1	{ ٤ } - { ـ }
# 1	{ ء } - { ث }
# 1	{ ٥ } - { ∴ }
# 1	{ ٧ } - {  }
# 1	{ ٨ } - { &#34; }
# 1	{ . } - { - }
# 1	{ و } - { ز }
# 1	{ ق } - { ى }
# 1	{  } - { ، }
# 1	{ ، } - {  }
# 1	{  } - { ى }
# 1	{  } - { ( }
# 1	{ ض } - {  }
# 1	{ ص } - { س }
# 1	{ ف } - { ث }
# 1	{ ء } - {  }
# 1	{ ٢ } - {  }
# 1	{ و } - {  }
# 1	{ ا } - { ARABIC SHADDA }
# 1	{ ٤ } - { &#34; }
# 1	{ و } - { ر }
# 1	{ ح } - { — }
# 1	{  } - { ب }
# 1	{ ك } - { SPACE }
# 1	{ م } - { ق }
# 1	{ ي } - { ت }
# 1	{ ٢ } - { ر }
# 1	{ ) } - { ـ }
# 1	{ ن } - { ل }
# 1	{ ) } - { SPACE }
# 1	{ ت } - { ك }
# 1	{ ، } - { SPACE }
# 1	{ ٤ } - {  }
# 1	{ ص } - { ع }
# 1	{ ٥ } - {  }
# 1	{ غ } - { ـ }
# 1	{  } - { ف }
# 1	{ ذ } - { ف }
# 1	{ ب } - { ه }
# 1	{ ∴ } - { . }
# 1	{  } - { ك }
# 1	{ . } - { ب }
# 1	{ ج } - { — }
#
# Average accuracy: 89.54%, (stddev: 0.00)

# %%
print('Time at start of below:\n\t',datetime.datetime.now())
# Out:
# Time at start of below:
# 	 2019-09-17 02:37:39.121380

# %%
# !ketos train --resize add -i out/1/model_best.mlmodel -o out/2/model phaenomena/5pgs/*.png
# Out:
# Building training set  [####################################]  100%
# [5.2477] alphabet mismatch: chars in training set only: {'٩', '٢', '/', '—', '-', 'ظ', 'َ', 'ؤ', '"', '١', 'ئ', 'ـ', 'ُ', 'ِ', '٥', 'ء'} (not included in accuracy test during training)
# [5.2478] alphabet mismatch: chars in validation set only: {'∴'} (not trained)
# Network codec not compatible with training set
# Adding missing labels to network ✓
# stage 1/∞  [####################################]  98/98          Accuracy report (1) 0.9498 458 23
# stage 2/∞  [####################################]  98/98          Accuracy report (2) 0.9585 458 19
# stage 3/∞  [####################################]  98/98          Accuracy report (3) 0.9607 458 18
# stage 4/∞  [####################################]  98/98          Accuracy report (4) 0.9651 458 16
# stage 5/∞  [####################################]  98/98          Accuracy report (5) 0.9629 458 17
# stage 6/∞  [####################################]  98/98          Accuracy report (6) 0.9716 458 13
# stage 7/∞  [####################################]  98/98          Accuracy report (7) 0.9651 458 16
# stage 8/∞  [####################################]  98/98          Accuracy report (8) 0.9738 458 12
# stage 9/∞  [####################################]  98/98          Accuracy report (9) 0.9716 458 13
# stage 10/∞  [####################################]  98/98          Accuracy report (10) 0.9672 458 15
# stage 11/∞  [####################################]  98/98          Accuracy report (11) 0.9716 458 13
# stage 12/∞  [####################################]  98/98          Accuracy report (12) 0.9694 458 14
# stage 13/∞  [####################################]  98/98          Accuracy report (13) 0.9738 458 12
#
# Moving best model out/2/model_8.mlmodel (0.9737991266375546) to out/2/model_best.mlmodel

# %%
print('Time at completion of above:\n\t',datetime.datetime.now())
# Out:
# Time at completion of above:
# 	 2019-09-17 02:41:34.895214

# %%
print('Time at start of below:\n\t',datetime.datetime.now())
# Out:
# Time at start of below:
# 	 2019-09-17 02:41:34.912302

# %%
# !ketos train --resize add -i out/2/model_best.mlmodel -o out/3/model phaenomena/n5pgs/*.png
# Out:
# Building training set  [####################################]  100%
# [4.6845] alphabet mismatch: chars in training set only: {'ْ', '٣', '٧', '٥', 'َ', 'ٌ', '٨', '٤', '٢', '∴', 'ش', 'ء', ']', 'ؤ', 'ً', 'ئ', 'ِ'} (not included in accuracy test during training)
# Network codec not compatible with training set
# Adding missing labels to network ✓
# stage 1/∞  [####################################]  90/90          Accuracy report (1) 0.9838 554 9
# stage 2/∞  [####################################]  90/90          Accuracy report (2) 0.9856 554 8
# stage 3/∞  [####################################]  90/90          Accuracy report (3) 0.9838 554 9
# stage 4/∞  [####################################]  90/90          Accuracy report (4) 0.9856 554 8
# stage 5/∞  [####################################]  90/90          Accuracy report (5) 0.9856 554 8
# stage 6/∞  [####################################]  90/90          Accuracy report (6) 0.9892 554 6
# stage 7/∞  [####################################]  90/90          Accuracy report (7) 0.9838 554 9
# stage 8/∞  [####################################]  90/90          Accuracy report (8) 0.9874 554 7
# stage 9/∞  [####################################]  90/90          Accuracy report (9) 0.9910 554 5
# stage 10/∞  [####################################]  90/90          Accuracy report (10) 0.9910 554 5
# stage 11/∞  [####################################]  90/90          Accuracy report (11) 0.9856 554 8
# stage 12/∞  [####################################]  90/90          Accuracy report (12) 0.9892 554 6
# stage 13/∞  [####################################]  90/90          Accuracy report (13) 0.9874 554 7
# stage 14/∞  [####################################]  90/90          Accuracy report (14) 0.9910 554 5
#
# Moving best model out/3/model_9.mlmodel (0.9909747292418772) to out/3/model_best.mlmodel

# %%
print('Time at completion of above:\n\t',datetime.datetime.now())
# Out:
# Time at completion of above:
# 	 2019-09-17 02:45:25.715138

# %% [markdown]
# _____________
#
# ## Step 3: Testing and Refining on Text B
#
# I have one other text with a typeface that, though similar, is more distant than Text A's typeface. Below, I test both the original model and the refined model from above on training data I have transcribed from Text B.
#
# Initial accuracy rates are lower: the original model has 74.18% accuracy, while the refined model has 80.24% accuracy.
#
# Retraining the refined model on Text B's training data brings this up to a new accuracy of 95.97% in ten minutes. I ended my experiment here, but further rounds of training (as I did above for Text A) could plausibly push this even higher.

# %%
# !ketos test -m out/1/model_best.mlmodel hyderabad/training_data/*.png
# Out:
# Loading model out/1/model_best.mlmodel	✓
# Evaluating out/1/model_best.mlmodel
# Evaluating  [####################################]  100%
# === report  ===
#
# 18113	Characters
# 4676	Errors
# 74.18%	Accuracy
#
# 1149	Insertions
# 1685	Deletions
# 1842	Substitutions
#
# Count	Missed	%Right
# 14062	2179	84.50%	Arabic
# 4051	812	79.96%	Common
#
# Errors	Correct-Generated
# 1176	{  } - { SPACE }
# 315	{ SPACE } - {  }
# 194	{ - } - { ـ }
# 169	{ م } - {  }
# 100	{ - } - {  }
# 93	{ ل } - { ا }
# 86	{ ي } - {  }
# 78	{ ا } - { أ }
# 73	{ ا } - { SPACE }
# 59	{ ا } - {  }
# 59	{ ر } - { ز }
# 57	{ ا } - { ] }
# 50	{ ل } - {  }
# 48	{  } - { ه }
# 47	{  } - { ا }
# 46	{ ر } - {  }
# 45	{  } - { ] }
# 44	{ م } - { د }
# 44	{ م } - { ه }
# 42	{ ر } - { SPACE }
# 40	{ ع } - {  }
# 40	{ آ } - { ا }
# 38	{  } - { ARABIC SHADDA }
# 36	{  } - { ن }
# 35	{ خ } - { ن }
# 35	{ ن } - {  }
# 34	{ م } - { SPACE }
# 32	{  } - { ل }
# 32	{ ن } - { ARABIC SHADDA }
# 29	{ ب } - { ي }
# 27	{ . } - { SPACE }
# 26	{  } - { م }
# 24	{ خ } - { SPACE }
# 23	{ . } - { ه }
# 23	{  } - { أ }
# 21	{ ب } - {  }
# 21	{ SPACE } - { ـ }
# 20	{ ن } - { ل }
# 18	{ ه } - {  }
# 18	{  } - { ARABIC FATHATAN }
# 18	{ س } - { ARABIC SHADDA }
# 18	{  } - { د }
# 18	{  } - { ز }
# 17	{ ت } - { ARABIC SHADDA }
# 17	{ - } - { ح }
# 17	{ ا } - { ل }
# 17	{ خ } - { ح }
# 17	{ ق } - { ت }
# 16	{ و } - { ه }
# 16	{ خ } - {  }
# 16	{  } - { ـ }
# 15	{  } - { ب }
# 15	{ ي } - { ب }
# 15	{ ص } - {  }
# 15	{ ت } - { ث }
# 14	{ ث } - {  }
# 14	{  } - { ر }
# 14	{ - } - { — }
# 13	{  } - { ت }
# 13	{ ت } - {  }
# 13	{ ف } - { ن }
# 13	{ ي } - { SPACE }
# 12	{ ح } - {  }
# 12	{  } - { ي }
# 11	{ د } - {  }
# 11	{ و } - {  }
# 11	{ آ } - { SPACE }
# 11	{ ى } - {  }
# 11	{ ن } - { SPACE }
# 10	{ م } - { . }
# 10	{ ل } - { &#34; }
# 10	{ ج } - {  }
# 10	{  } - { س }
# 9	{ آ } - {  }
# 9	{  } - { ف }
# 9	{ ن } - { ف }
# 9	{ ث } - { ت }
# 9	{ ث } - { ن }
# 9	{ س } - {  }
# 9	{ ف } - {  }
# 8	{ ١ } - { SPACE }
# 8	{ ة } - {  }
# 8	{ ث } - { &#34; }
# 8	{ ع } - { م }
# 8	{ ئ } - { SPACE }
# 8	{ ق } - {  }
# 8	{ ح } - { خ }
# 7	{ ئ } - {  }
# 7	{ ش } - { ت }
# 7	{ م } - { - }
# 7	{  } - { &#34; }
# 7	{ ٥ } - { ه }
# 7	{  } - { ث }
# 7	{ ض } - {  }
# 7	{ ا } - { ز }
# 6	{ ت } - { ن }
# 6	{ م } - { ب }
# 6	{  } - { و }
# 6	{ م } - { س }
# 6	{  } - { ح }
# 6	{ ع } - { ه }
# 6	{ &gt; } - {  }
# 6	{ - } - { س }
# 6	{ ج } - { ب }
# 6	{  } - { ؟ }
# 5	{ ا } - { ن }
# 5	{ ر } - { د }
# 5	{ ٣ } - { ه }
# 5	{ ٢ } - {  }
# 5	{ ئ } - { ARABIC SHADDA }
# 5	{ خ } - { ا }
# 5	{ آ } - { ن }
# 5	{ ر } - { و }
# 5	{ ا } - { ه }
# 5	{ SPACE } - { ن }
# 5	{ و } - { SPACE }
# 5	{ - } - { د }
# 5	{ ن } - { ذ }
# 5	{ SPACE } - { ا }
# 5	{ خ } - { ARABIC FATHATAN }
# 5	{ ل } - { ن }
# 5	{ ا } - { إ }
# 4	{  } - { ى }
# 4	{ SPACE } - { ق }
# 4	{ خ } - { ARABIC SHADDA }
# 4	{ . } - { ء }
# 4	{ ٦ } - {  }
# 4	{ SPACE } - { ل }
# 4	{ ١ } - { ه }
# 4	{ ر } - { ن }
# 4	{ ي } - { ز }
# 4	{ ٧ } - {  }
# 4	{ ا } - { [ }
# 4	{ ب } - { SPACE }
# 4	{ ل } - { أ }
# 4	{ آ } - { ARABIC FATHATAN }
# 4	{ ٩ } - { ه }
# 4	{  } - { . }
# 4	{  } - { [ }
# 4	{ ش } - { ن }
# 4	{ - } - { SPACE }
# 4	{ ج } - { SPACE }
# 4	{ - } - { ه }
# 4	{ ق } - { ف }
# 4	{ ع } - { و }
# 3	{ ى } - { SPACE }
# 3	{  } - { ج }
# 3	{ ٥ } - { SPACE }
# 3	{ SPACE } - { ه }
# 3	{ م } - { ق }
# 3	{ د } - { ل }
# 3	{ SPACE } - { ز }
# 3	{ ل } - { SPACE }
# 3	{ ذ } - { ARABIC SHADDA }
# 3	{ ن } - { م }
# 3	{ ي } - { ه }
# 3	{ آ } - { أ }
# 3	{ ا } - { و }
# 3	{  } - { ء }
# 3	{ ذ } - { SPACE }
# 3	{ ق } - { ن }
# 3	{ ن } - { س }
# 3	{ ١ } - {  }
# 3	{ ب } - { ه }
# 3	{ م } - { &#34; }
# 3	{ ٣ } - { ب }
# 3	{ SPACE } - { ي }
# 3	{ ف } - { ذ }
# 3	{ ص } - { ع }
# 3	{ آ } - { ARABIC SHADDA }
# 3	{ س } - { م }
# 3	{ &lt; } - { SPACE }
# 3	{  } - { إ }
# 3	{ ف } - { ل }
# 3	{ خ } - { ف }
# 3	{ ٧ } - { SPACE }
# 3	{ ن } - { خ }
# 3	{ ف } - { ARABIC SHADDA }
# 2	{ ح } - { SPACE }
# 2	{ ج } - { م }
# 2	{ ل } - { ت }
# 2	{ م } - { ز }
# 2	{  } - { ش }
# 2	{  } - { ع }
# 2	{ ج } - { ح }
# 2	{ ٣ } - { س }
# 2	{ آ } - { ] }
# 2	{ ر } - { ARABIC FATHATAN }
# 2	{ م } - { ل }
# 2	{ ة } - { و }
# 2	{ SPACE } - { أ }
# 2	{ ء } - { ه }
# 2	{ SPACE } - { ب }
# 2	{ ي } - { د }
# 2	{ SPACE } - { ] }
# 2	{ م } - { ] }
# 2	{ ك } - {  }
# 2	{ ث } - { SPACE }
# 2	{ ب } - { ت }
# 2	{ ق } - { SPACE }
# 2	{ SPACE } - { ح }
# 2	{ ر } - { ح }
# 2	{ د } - { SPACE }
# 2	{ - } - { و }
# 2	{ ج } - { ي }
# 2	{ ء } - {  }
# 2	{ ض } - { ن }
# 2	{ ض } - { ف }
# 2	{ ي } - { ت }
# 2	{ ت } - { ش }
# 2	{ م } - { ث }
# 2	{ و } - { د }
# 2	{ ث } - { ك }
# 2	{ ٥ } - {  }
# 2	{ - } - { ج }
# 2	{ ٠ } - { SPACE }
# 2	{ ة } - { ARABIC FATHATAN }
# 2	{ ي } - { ا }
# 2	{ ى } - { ف }
# 2	{ &lt; } - { ه }
# 2	{ ٦ } - { ه }
# 2	{ ٢ } - { ه }
# 2	{ ٦ } - { ب }
# 2	{ ص } - { م }
# 2	{ ن } - { ز }
# 2	{ ع } - { ء }
# 2	{ ي } - { ARABIC SHADDA }
# 2	{ ٨ } - {  }
# 2	{ &lt; } - {  }
# 2	{  } - { ك }
# 2	{ م } - { ف }
# 2	{ ي } - { ئ }
# 2	{ ٤ } - { SPACE }
# 2	{ &gt; } - { SPACE }
# 2	{ ث } - { ئ }
# 2	{  } - { + }
# 2	{ ه } - { ي }
# 2	{ ى } - { ARABIC SHADDA }
# 2	{ ب } - { ج }
# 1	{ ر } - { ـ }
# 1	{ ي } - { ل }
# 1	{ ف } - { SPACE }
# 1	{ د } - { ن }
# 1	{ ي } - { ع }
# 1	{  } - { خ }
# 1	{ غ } - {  }
# 1	{ ل } - { ARABIC SHADDA }
# 1	{ ة } - { ت }
# 1	{ ه } - { ث }
# 1	{ ع } - { ـ }
# 1	{ ٨ } - { م }
# 1	{ ة } - { ر }
# 1	{ ن } - { ه }
# 1	{ ح } - { ق }
# 1	{ س } - { ح }
# 1	{ ت } - { ل }
# 1	{ ه } - { ARABIC SHADDA }
# 1	{ ش } - {  }
# 1	{ و } - { ف }
# 1	{ ق } - { ARABIC SHADDA }
# 1	{ ي } - { م }
# 1	{ ي } - { أ }
# 1	{ &lt; } - { ، }
# 1	{ ١ } - { د }
# 1	{ ش } - { ك }
# 1	{ ت } - { م }
# 1	{ - } - { ة }
# 1	{ خ } - { و }
# 1	{ SPACE } - { ج }
# 1	{ - } - { ا }
# 1	{ ا } - { ب }
# 1	{ ن } - { ا }
# 1	{ ن } - { ] }
# 1	{ م } - { ى }
# 1	{ ة } - { SPACE }
# 1	{ م } - { ARABIC FATHATAN }
# 1	{ ر } - { ل }
# 1	{ م } - { ر }
# 1	{ ذ } - { &#34; }
# 1	{ ا } - { م }
# 1	{ ٨ } - { ه }
# 1	{ ز } - { SPACE }
# 1	{ ث } - { ر }
# 1	{ SPACE } - { خ }
# 1	{ ١ } - { ، }
# 1	{ س } - { ـ }
# 1	{ ق } - { م }
# 1	{ ع } - { SPACE }
# 1	{ ق } - { ز }
# 1	{ ع } - { ق }
# 1	{ و } - { ر }
# 1	{ ز } - { ARABIC SHADDA }
# 1	{ - } - { ARABIC SHADDA }
# 1	{ ز } - {  }
# 1	{ SPACE } - { س }
# 1	{ ك } - { SPACE }
# 1	{ خ } - { ج }
# 1	{ س } - { ذ }
# 1	{ ع } - { ا }
# 1	{ ب } - { ا }
# 1	{ ح } - { ى }
# 1	{ ك } - { ؟ }
# 1	{ ي } - { ف }
# 1	{ ٢ } - { SPACE }
# 1	{ ٠ } - { . }
# 1	{ ف } - { ] }
# 1	{ م } - { ا }
# 1	{ ذ } - {  }
# 1	{ ا } - { ـ }
# 1	{ ه } - { ت }
# 1	{ ٤ } - { س }
# 1	{ - } - { . }
# 1	{ خ } - { ذ }
# 1	{ ض } - { خ }
# 1	{ ك } - { &#34; }
# 1	{ ط } - { SPACE }
# 1	{  } - { ة }
# 1	{ د } - { ا }
# 1	{  } - { ئ }
# 1	{ م } - { ئ }
# 1	{ ت } - { ا }
# 1	{ ٤ } - { ه }
# 1	{ ص } - { أ }
# 1	{ ا } - { . }
# 1	{ SPACE } - { د }
# 1	{ ٨ } - { ا }
# 1	{  } - { - }
# 1	{ د } - { — }
# 1	{ ت } - { ه }
# 1	{ د } - { ث }
# 1	{ س } - { &#34; }
# 1	{ ز } - { ن }
# 1	{ ن } - { ح }
# 1	{ س } - { ك }
# 1	{ ٥ } - { ؛ }
# 1	{ ٤ } - {  }
# 1	{ ظ } - { ل }
# 1	{ ط } - { ل }
# 1	{ ٠ } - {  }
# 1	{ ر } - { م }
# 1	{ ن } - { ؛ }
# 1	{ ٦ } - { ٩ }
# 1	{ ل } - { إ }
# 1	{ ة } - { د }
# 1	{ ٦ } - { SPACE }
# 1	{  } - { ٠ }
# 1	{ ف } - { م }
# 1	{ SPACE } - { [ }
# 1	{  } - { — }
# 1	{ ع } - { ح }
# 1	{ آ } - { ؟ }
# 1	{ &lt; } - { + }
# 1	{ &gt; } - { د }
# 1	{ ت } - { ب }
# 1	{ SPACE } - { ARABIC SHADDA }
# 1	{  } - { ض }
# 1	{ - } - { ل }
# 1	{ ٣ } - { ٠ }
# 1	{ ذ } - { ل }
# 1	{ ب } - { ؟ }
# 1	{ . } - {  }
# 1	{ س } - { ل }
# 1	{ ي } - { ذ }
# 1	{ - } - { ي }
# 1	{ ٧ } - { ر }
# 1	{ ئ } - { ن }
# 1	{ ٧ } - { ه }
# 1	{ ٩ } - {  }
# 1	{ SPACE } - { إ }
# 1	{  } - { ذ }
# 1	{ و } - { ل }
# 1	{ ق } - { ا }
# 1	{ ب } - { ن }
# 1	{ ط } - { [ }
# 1	{ ت } - { ذ }
# 1	{ ك } - { و }
# 1	{ ٨ } - { و }
# 1	{ ا } - { &#34; }
# 1	{ ٨ } - { ١ }
# 1	{ ع } - { أ }
# 1	{ ت } - { ـ }
# 1	{ ن } - { ت }
# 1	{ ٨ } - { ر }
# 1	{ ٩ } - { SPACE }
# 1	{ ف } - { ز }
# 1	{ ه } - { م }
# 1	{ ر } - { ب }
# 1	{  } - { ق }
# 1	{  } - { ص }
# 1	{ ل } - { ] }
# 1	{ ص } - { خ }
# 1	{ SPACE } - { — }
# 1	{ خ } - { م }
# 1	{ - } - { ب }
# 1	{ س } - { ف }
# 1	{ ب } - { [ }
# 1	{ و } - { م }
# 1	{ و } - { ا }
# 1	{ ج } - { ـ }
# 1	{ ب } - { م }
# 1	{ SPACE } - { ARABIC FATHATAN }
# 1	{ - } - { ء }
# 1	{ ى } - { ه }
# 1	{ ش } - { د }
# 1	{ - } - { ] }
# 1	{ ب } - { ـ }
# 1	{ د } - { ي }
# 1	{ ة } - { ARABIC SHADDA }
# 1	{ ي } - { ن }
# 1	{ م } - { ح }
# 1	{ ى } - { ش }
# 1	{ ع } - { ت }
# 1	{ ت } - { SPACE }
# 1	{ م } - { ذ }
# 1	{ ع } - { ك }
# 1	{ ا } - { ؛ }
# 1	{ ن } - { أ }
# 1	{ - } - { أ }
# 1	{ د } - { ] }
# 1	{ ئ } - { ت }
# 1	{ ث } - { ـ }
# 1	{ م } - { ت }
# 1	{ SPACE } - { ة }
# 1	{ ه } - { ل }
# 1	{ ١ } - { ARABIC FATHATAN }
#
# Average accuracy: 74.18%, (stddev: 0.00)

# %%
# !ketos test -m out/3/model_best.mlmodel hyderabad/training_data/*.png
# Out:
# Loading model out/3/model_best.mlmodel	✓
# Evaluating out/3/model_best.mlmodel
# Evaluating  [####################################]  100%
# === report  ===
#
# 18113	Characters
# 3579	Errors
# 80.24%	Accuracy
#
# 1374	Insertions
# 1066	Deletions
# 1139	Substitutions
#
# Count	Missed	%Right
# 14062	1859	86.78%	Arabic
# 4051	654	83.86%	Common
#
# Errors	Correct-Generated
# 818	{  } - { SPACE }
# 380	{ SPACE } - {  }
# 175	{ م } - {  }
# 103	{ - } - { ـ }
# 93	{ ي } - {  }
# 90	{ ع } - {  }
# 74	{ - } - {  }
# 70	{ ل } - { ا }
# 69	{ ل } - {  }
# 64	{ ا } - {  }
# 60	{ خ } - { ن }
# 48	{ س } - {  }
# 40	{ ر } - {  }
# 33	{ خ } - { ح }
# 32	{ ت } - {  }
# 32	{ ن } - {  }
# 32	{ آ } - { ا }
# 31	{ ع } - { م }
# 26	{  } - { ن }
# 26	{  } - { ا }
# 25	{ ث } - {  }
# 24	{ ا } - { SPACE }
# 24	{ م } - { . }
# 23	{ ف } - {  }
# 23	{ . } - { SPACE }
# 23	{ ق } - { ت }
# 22	{ آ } - {  }
# 21	{ ث } - { ك }
# 20	{ ا } - { أ }
# 20	{ ى } - {  }
# 20	{  } - { ر }
# 19	{ ا } - { ل }
# 18	{ م } - { SPACE }
# 18	{ ب } - {  }
# 18	{ م } - { ه }
# 18	{ ر } - { SPACE }
# 17	{ خ } - {  }
# 17	{ ن } - { ل }
# 16	{ و } - {  }
# 16	{  } - { ل }
# 16	{ خ } - { SPACE }
# 15	{ ه } - {  }
# 15	{ SPACE } - { ـ }
# 14	{ م } - { د }
# 14	{ ب } - { ي }
# 14	{  } - { م }
# 14	{  } - { ] }
# 14	{ ن } - { ذ }
# 13	{ ا } - { ] }
# 13	{  } - { د }
# 12	{ ي } - { SPACE }
# 12	{  } - { ه }
# 12	{  } - { و }
# 12	{ آ } - { أ }
# 11	{ ح } - {  }
# 11	{  } - { أ }
# 11	{ ع } - { ه }
# 11	{ ك } - {  }
# 11	{  } - { . }
# 11	{ ف } - { ن }
# 10	{ آ } - { SPACE }
# 10	{ ر } - { ز }
# 10	{ ت } - { ث }
# 10	{ ١ } - {  }
# 9	{ ة } - {  }
# 9	{  } - { ت }
# 9	{ ش } - { ت }
# 9	{  } - { ب }
# 8	{ ر } - { و }
# 8	{  } - { ARABIC FATHATAN }
# 8	{ ٣ } - {  }
# 8	{ ت } - { ن }
# 8	{ ث } - { ن }
# 8	{ ٧ } - {  }
# 7	{ ر } - { د }
# 7	{ ج } - {  }
# 7	{ ن } - { أ }
# 7	{ ئ } - {  }
# 7	{ ث } - { ئ }
# 7	{ ٦ } - {  }
# 7	{ ج } - { ب }
# 7	{ ن } - { ت }
# 6	{ ث } - { ت }
# 6	{ ٥ } - { ه }
# 6	{  } - { ك }
# 5	{ ١ } - { SPACE }
# 5	{ ق } - {  }
# 5	{ &gt; } - {  }
# 5	{ ٨ } - {  }
# 5	{ خ } - { ا }
# 5	{ خ } - { ف }
# 5	{ ئ } - { SPACE }
# 4	{ م } - { ب }
# 4	{ ل } - { SPACE }
# 4	{ ي } - { ب }
# 4	{ SPACE } - { ن }
# 4	{ س } - { ل }
# 4	{ ٢ } - {  }
# 4	{  } - { ـ }
# 4	{ ن } - { SPACE }
# 4	{ ث } - { SPACE }
# 4	{ ٩ } - {  }
# 4	{ ٤ } - {  }
# 4	{ ٥ } - { SPACE }
# 4	{  } - { ي }
# 4	{ ش } - { ن }
# 3	{ ح } - { SPACE }
# 3	{ ئ } - { ت }
# 3	{ ش } - {  }
# 3	{ SPACE } - { أ }
# 3	{ ض } - { ف }
# 3	{ &lt; } - { ، }
# 3	{ SPACE } - { ق }
# 3	{ و } - { ه }
# 3	{ ق } - { ن }
# 3	{ ه } - { SPACE }
# 3	{ ف } - { ذ }
# 3	{ و } - { د }
# 3	{ SPACE } - { د }
# 3	{  } - { ز }
# 3	{  } - { - }
# 3	{ ل } - { ن }
# 3	{ ج } - { ح }
# 3	{  } - { ، }
# 3	{ س } - { ذ }
# 3	{ SPACE } - { ل }
# 3	{ ض } - {  }
# 3	{ ٩ } - { ه }
# 2	{  } - { ف }
# 2	{  } - { ح }
# 2	{ ج } - { م }
# 2	{ ه } - { ب }
# 2	{ م } - { ت }
# 2	{ ه } - { ي }
# 2	{ - } - { SPACE }
# 2	{ د } - { SPACE }
# 2	{ ع } - { ا }
# 2	{ ر } - { ا }
# 2	{ ا } - { ( }
# 2	{ ن } - { ف }
# 2	{ م } - { ق }
# 2	{ ن } - { ر }
# 2	{ . } - { ه }
# 2	{ SPACE } - { ا }
# 2	{ د } - {  }
# 2	{ م } - { ر }
# 2	{ ا } - { م }
# 2	{ ب } - { ت }
# 2	{ ز } - { SPACE }
# 2	{ ع } - { SPACE }
# 2	{ و } - { SPACE }
# 2	{ ز } - {  }
# 2	{ ب } - { SPACE }
# 2	{ ض } - { ن }
# 2	{ ب } - { م }
# 2	{ ٢ } - { ه }
# 2	{ ٠ } - { . }
# 2	{ ة } - { ء }
# 2	{ م } - { ، }
# 2	{ ه } - { ت }
# 2	{ خ } - { غ }
# 2	{ ئ } - { أ }
# 2	{ ت } - { ب }
# 2	{ ي } - { ا }
# 2	{ SPACE } - { . }
# 2	{ ٠ } - {  }
# 2	{ ش } - { ث }
# 2	{  } - { ع }
# 2	{ ت } - { م }
# 2	{ ت } - { ه }
# 2	{ ف } - { ل }
# 2	{ &lt; } - { ه }
# 2	{ خ } - { أ }
# 2	{ ى } - { ف }
# 2	{ ي } - { ئ }
# 2	{ خ } - { و }
# 2	{ ق } - { ف }
# 2	{ ئ } - { م }
# 2	{  } - { ج }
# 2	{ خ } - { ذ }
# 1	{ ر } - { ـ }
# 1	{ ف } - { ه }
# 1	{ د } - { ن }
# 1	{ ل } - { ت }
# 1	{ ط } - { ى }
# 1	{ م } - { ص }
# 1	{ ه } - { ث }
# 1	{ ع } - { غ }
# 1	{ آ } - { ة }
# 1	{ ٣ } - { SPACE }
# 1	{ ٥ } - { م }
# 1	{ ٨ } - { ه }
# 1	{ SPACE } - { ر }
# 1	{ ة } - { م }
# 1	{ ن } - { ش }
# 1	{ SPACE } - { ARABIC FATHATAN }
# 1	{ ٢ } - { ـ }
# 1	{ - } - { ى }
# 1	{ - } - { ت }
# 1	{ ت } - { ل }
# 1	{ SPACE } - { و }
# 1	{ ة } - { أ }
# 1	{ ١ } - { د }
# 1	{ ى } - { - }
# 1	{ SPACE } - { ة }
# 1	{ س } - { ر }
# 1	{ ن } - { ا }
# 1	{ ن } - { ] }
# 1	{ م } - { ن }
# 1	{ س } - { أ }
# 1	{ ة } - { SPACE }
# 1	{ ٥ } - {  }
# 1	{ - } - { د }
# 1	{ ى } - { د }
# 1	{ ى } - { ARABIC FATHATAN }
# 1	{ ي } - { غ }
# 1	{ ر } - { ن }
# 1	{ ا } - { ز }
# 1	{ ح } - { ع }
# 1	{ س } - { ـ }
# 1	{  } - { غ }
# 1	{ ز } - { ن }
# 1	{ SPACE } - { ذ }
# 1	{ ل } - { ] }
# 1	{ خ } - { ج }
# 1	{ ء } - {  }
# 1	{ ا } - { ه }
# 1	{  } - { ة }
# 1	{  } - { ١ }
# 1	{ ت } - { ق }
# 1	{ ك } - { ا }
# 1	{ ل } - { ذ }
# 1	{ ٣ } - { ب }
# 1	{ ف } - { م }
# 1	{ ت } - { ش }
# 1	{ ق } - { ة }
# 1	{ ل } - { ز }
# 1	{  } - { خ }
# 1	{ - } - { . }
# 1	{ ٣ } - { ه }
# 1	{ ٢ } - { . }
# 1	{ ط } - { ة }
# 1	{  } - { س }
# 1	{  } - { ش }
# 1	{ ث } - { د }
# 1	{ ء } - { ه }
# 1	{ ت } - { ا }
# 1	{  } - { ئ }
# 1	{ ٤ } - { SPACE }
# 1	{ ا } - { . }
# 1	{ SPACE } - { ى }
# 1	{  } - { ث }
# 1	{ ٨ } - { ١ }
# 1	{ ا } - { إ }
# 1	{ ز } - { ذ }
# 1	{ ن } - { ب }
# 1	{ س } - { ك }
# 1	{ ٥ } - { ، }
# 1	{ س } - { ن }
# 1	{ ن } - { و }
# 1	{ ى } - { ا }
# 1	{ ى } - { SPACE }
# 1	{ ح } - { خ }
# 1	{ ن } - { ع }
# 1	{ ط } - { ل }
# 1	{ م } - { أ }
# 1	{  } - { ( }
# 1	{ &lt; } - { ؛ }
# 1	{ &gt; } - { ا }
# 1	{ ٦ } - { ٢ }
# 1	{ ٦ } - { ب }
# 1	{ ل } - { م }
# 1	{ ن } - { م }
# 1	{ &lt; } - { م }
# 1	{ ٦ } - { ه }
# 1	{ ى } - { ل }
# 1	{ ض } - { خ }
# 1	{ س } - { م }
# 1	{ &gt; } - { د }
# 1	{ خ } - { د }
# 1	{ ض } - { ذ }
# 1	{  } - { ض }
# 1	{ م } - { و }
# 1	{ &lt; } - { ٨ }
# 1	{ ١ } - { ه }
# 1	{ آ } - { ن }
# 1	{ ج } - { SPACE }
# 1	{ ي } - { ث }
# 1	{ ٧ } - { SPACE }
# 1	{  } - { ٢ }
# 1	{ &gt; } - { ه }
# 1	{ ت } - { ي }
# 1	{ . } - {  }
# 1	{ ي } - { ت }
# 1	{ ث } - { م }
# 1	{ ف } - { ق }
# 1	{ ع } - { و }
# 1	{ ي } - { ش }
# 1	{ ا } - { ن }
# 1	{ ض } - { غ }
# 1	{ ٨ } - { . }
# 1	{ &lt; } - { SPACE }
# 1	{ ١ } - { ، }
# 1	{ &gt; } - { SPACE }
# 1	{ ل } - { ئ }
# 1	{ ق } - { ا }
# 1	{ ب } - { ن }
# 1	{ ط } - { SPACE }
# 1	{ ت } - { ] }
# 1	{ ل } - { ع }
# 1	{ ع } - { ذ }
# 1	{ م } - { خ }
# 1	{ ق } - { SPACE }
# 1	{ ٨ } - { ب }
# 1	{ ت } - { ع }
# 1	{ ب } - { ه }
# 1	{ - } - { ن }
# 1	{ ٨ } - { SPACE }
# 1	{ ت } - { ج }
# 1	{ SPACE } - { ٢ }
# 1	{ ه } - { ا }
# 1	{ ئ } - { ل }
# 1	{ خ } - { ل }
# 1	{ ح } - { ج }
# 1	{ ٠ } - { SPACE }
# 1	{ ع } - { ل }
# 1	{ ئ } - { ن }
# 1	{ ف } - { ب }
# 1	{  } - { إ }
# 1	{ ف } - { SPACE }
# 1	{ خ } - { م }
# 1	{  } - { ق }
# 1	{  } - { ص }
# 1	{ SPACE } - { ب }
# 1	{ س } - { ف }
# 1	{ - } - { ي }
# 1	{ ب } - { ٢ }
# 1	{ ط } - {  }
# 1	{  } - { ذ }
# 1	{ - } - { ج }
# 1	{ - } - { ل }
# 1	{ ى } - { ه }
# 1	{  } - { ء }
# 1	{ ه } - { م }
# 1	{ ه } - { خ }
# 1	{ ل } - { ة }
#
# Average accuracy: 80.24%, (stddev: 0.00)

# %%
print('Time at start of below:\n\t',datetime.datetime.now())
# Out:
# Time at start of below:
# 	 2019-09-17 02:46:24.507642

# %%
# !ketos train --resize add -i out/3/model_best.mlmodel -o out/4/model hyderabad/training_data/*.png
# Out:
# Building training set  [####################################]  100%
# Building validation set  [####################################]  100%
# [16.2385] alphabet mismatch: chars in training set only: {'٧', 'غ', '٦', 'أ', '٩', '٠', 'ء'} (not included in accuracy test during training)
# Network codec not compatible with training set
# Adding missing labels to network ✓
# stage 1/∞  [####################################]  361/361          Accuracy report (1) 0.9280 1737 125
# stage 2/∞  [####################################]  361/361          Accuracy report (2) 0.9349 1737 113
# stage 3/∞  [####################################]  361/361          Accuracy report (3) 0.9476 1737 91
# stage 4/∞  [####################################]  361/361          Accuracy report (4) 0.9499 1737 87
# stage 5/∞  [####################################]  361/361          Accuracy report (5) 0.9522 1737 83
# stage 6/∞  [####################################]  361/361          Accuracy report (6) 0.9597 1737 70
# stage 7/∞  [####################################]  361/361          Accuracy report (7) 0.9585 1737 72
# stage 8/∞  [####################################]  361/361          Accuracy report (8) 0.9574 1737 74
# stage 9/∞  [####################################]  361/361          Accuracy report (9) 0.9551 1737 78
# stage 10/∞  [####################################]  361/361          Accuracy report (10) 0.9614 1737 67
# stage 11/∞  [####################################]  361/361          Accuracy report (11) 0.9597 1737 70
#
# Moving best model out/4/model_6.mlmodel (0.9597006332757628) to out/4/model_best.mlmodel

# %%
print('Time at completion of above:\n\t',datetime.datetime.now())
# Out:
# Time at completion of above:
# 	 2019-09-17 02:56:49.801231
